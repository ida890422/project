# %% [markdown]
# <a href="https://colab.research.google.com/github/ida890422/project/blob/main/0530_Ida_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls '/content/drive/MyDrive/colab'
# Out:
#  inside-out-screenplay.txt   kinglear.txt   pride-and-prejudice.txt  'Thomas More-Utopia.txt'

# %%
import nltk
nltk.download('popular')
nltk.download('all-corpora')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
import nltk

from nltk.corpus import PlaintextCorpusReader

corpus_root = '/content/drive/MyDrive/colab'
wordlists = PlaintextCorpusReader(corpus_root, '.*')

books = wordlists.fileids()
print(books)
# Out:
# ['Thomas More-Utopia.txt', 'inside-out-screenplay.txt', 'kinglear.txt', 'pride-and-prejudice.txt']

# %%
import nltk
testText = wordlists.words('kinglear.txt')
single = nltk.text.Text(testText)
print(single)
# Out:
# <Text: 1606 THE TRAGEDY OF KING LEAR by William...>

# %%
import nltk
testText = wordlists.words('kinglear.txt')
single = nltk.text.Text(testText)

findList = ["a","the", "can", "lord"]
single.dispersion_plot(findList)

# %%
books = wordlists.fileids()

cfd = nltk.ConditionalFreqDist((fileid, word)
    for fileid in books
    for word in wordlists.words(fileid)
    )

findList = ['can', 'could', 'may', 'might', 'must', 'will', 'shall', 'should']
cfd.tabulate(conditions=books, samples=findList)
# Out:
#                              can  could    may  might   must   will  shall should
#    Thomas More-Utopia.txt     96     59    137     60     47    109     19     80
# inside-out-screenplay.txt     59     13      2      4      1     19      0      8
#              kinglear.txt     37     17     44      9     44    110     84     39
#   pride-and-prejudice.txt    201    515    184    200    304    396    157    244

# %%
books = wordlists.fileids()
print(books)
# Out:
# ['Thomas More-Utopia.txt', 'inside-out-screenplay.txt', 'kinglear.txt', 'pride-and-prejudice.txt']

# %%
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:7])
    for fileid in wordlists.fileids()
    for w in wordlists.words(fileid)
    for target in ['lord', 'kingdom']
    if w.lower() == target) # w.lower().startswith(target)
cfd.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'no', 'ours', 'because', 'an', 'is', 'were', 'yourselves', 'shall', 'or', "when's", 'not', 'also', 'and', 'before', 'until', 'whom', 'on', "she'd", "you'd", "i'd", 'under', "what's", 'as', 'between', "here's", 'by', 'to', "mustn't", 'himself', 'which', "let's", 'while', 'do', 'could', "hadn't", "couldn't", 'his', "haven't", 'been', 'most', "we've", 'again', 'above', 'otherwise', "he'll", 'being', "that's", 'only', 'against', 'had', 'com', 'theirs', "wasn't", 'with', 'www', 'over', "i'm", 'hence', "i'll", 'herself', 'they', 'your', 'other', 'but', "there's", 'once', 'was', "won't", 'some', 'at', 'it', 'hers', "isn't", 'here', 'myself', 'then', 'same', 'has', 'what', 'k', "he's", 'where', "you've", "it's", 'how', 'more', 'get', 'did', 'yourself', 'him', 'the', 'am', 'yours', 'such', "we'll", 'would', 'their', 'there', 'all', 'our', 'should', "they've", "weren't", 'nor', 'ourselves', "we'd", 'else', 'during', "aren't", 'just', "where's", 'those', "we're", 'we', 'since', 'her', 'are', '
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

file_text = open('/content/drive/MyDrive/colab/kinglear.txt','r').read()



wordcloud = WordCloud(
    background_color="pink",
    width=2000,
    height=1000,
    margin= 10,
).generate(file_text)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'no', 'ours', 'because', 'an', 'is', 'were', 'yourselves', 'shall', 'or', "when's", 'not', 'also', 'and', 'before', 'until', 'whom', 'on', "she'd", "you'd", "i'd", 'under', "what's", 'as', 'between', "here's", 'by', 'to', "mustn't", 'himself', 'which', "let's", 'while', 'do', 'could', "hadn't", "couldn't", 'his', "haven't", 'been', 'most', "we've", 'again', 'above', 'otherwise', "he'll", 'being', "that's", 'only', 'against', 'had', 'com', 'theirs', "wasn't", 'with', 'www', 'over', "i'm", 'hence', "i'll", 'herself', 'they', 'your', 'other', 'but', "there's", 'once', 'was', "won't", 'some', 'at', 'it', 'hers', "isn't", 'here', 'myself', 'then', 'same', 'has', 'what', 'k', "he's", 'where', "you've", "it's", 'how', 'more', 'get', 'did', 'yourself', 'him', 'the', 'am', 'yours', 'such', "we'll", 'would', 'their', 'there', 'all', 'our', 'should', "they've", "weren't", 'nor', 'ourselves', "we'd", 'else', 'during', "aren't", 'just', "where's", 'those', "we're", 'we', 'since', 'her', 'are', '
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/colab/kinglear.txt','r').read()

# stopwords 停用字詞
stop = ["thing", "much", "said", "one"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="yellow",
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import nltk

from nltk.corpus import PlaintextCorpusReader

corpus_root = '/content/drive/My Drive/colab'
wordlists = PlaintextCorpusReader(corpus_root, '.*')

books = wordlists.fileids()
print(books)
# Out:
# ['Thomas More-Utopia.txt', 'inside-out-screenplay.txt', 'kinglear.txt', 'pride-and-prejudice.txt']

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


stop = list(STOPWORDS)

for fileid in books:
  f = open('/content/drive/My Drive/colab/'+fileid,'r').read()
  wordcloud = WordCloud(
      background_color="white",
      width=1500,
      height=1200,
      margin=2,
      stopwords=stop
  ).generate(f)

  plt.imshow(wordcloud)
  plt.axis("off")
  print(fileid)
  plt.show()
# Out:
# Thomas More-Utopia.txt
# inside-out-screenplay.txt
# kinglear.txt
# pride-and-prejudice.txt
